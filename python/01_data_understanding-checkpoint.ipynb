# %%
import pandas as pd
import os

# %%
data_path = r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data"

os.listdir(data_path)
# Out:
# ['olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv',
#  'raw']

# %%
import pandas as pd

customers = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_customers_dataset.csv")
geolocation = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_geolocation_dataset.csv")
orders = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_orders_dataset.csv")
order_items = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_order_items_dataset.csv")
payments = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_order_payments_dataset.csv")
reviews = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_order_reviews_dataset.csv")
products = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_products_dataset.csv")
sellers = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\olist_sellers_dataset.csv")
category_translation = pd.read_csv(r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\data\product_category_name_translation.csv")

# %%
datasets = {
    "Customers": customers,
    "Geolocation": geolocation,
    "Orders": orders,
    "Order Items": order_items,
    "Payments": payments,
    "Reviews": reviews,
    "Products": products,
    "Sellers": sellers,
    "Category Translation": category_translation
}

# %%
for name, df in datasets.items():
    print(f"{name}: {df.shape[0]:,} rows * {df.shape[1]} columns")
# Out:
# Customers: 99,441 rows * 5 columns
# Geolocation: 1,000,163 rows * 5 columns
# Orders: 99,441 rows * 8 columns
# Order Items: 112,650 rows * 7 columns
# Payments: 103,886 rows * 5 columns
# Reviews: 99,224 rows * 7 columns
# Products: 32,951 rows * 9 columns
# Sellers: 3,095 rows * 4 columns
# Category Translation: 71 rows * 2 columns

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders[orders["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %% [markdown]
# Business interpretation
#
# Canceled → customer never received the order.
# Unavailable → order couldn't be fulfilled.
# Processing / Invoiced / Approved / Created → order hasn't reached delivery.
# Shipped → shipment hasn't been recorded as delivered yet.
# Delivered + missing date (8) → these are potential data-quality issues that we should investigate later.

# %%
orders[
    (orders["order_status"] == "delivered") &
    (orders["order_delivered_customer_date"].isnull())
]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07  2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43  2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11  2018-07-01 17:15:12
# ...

# %%
orders["order_id"].duplicated().sum()
# Out:
# 0

# %%
# Customer Table
customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers["customer_id"].duplicated().sum()
# Out:
# 0

# %%
# Check whether customers repeat
customers["customer_unique_id"].duplicated().sum()
# Out:
# 3345

# %%
# Find actual repeat customers
customers["customer_unique_id"].value_counts()
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# ca77025e7201e3b30c44b472ff346268     7
# 6469f99c1f9dfae7733b25662e7f1782     7
#                                     ..
# 081f07439678af2da7755a0aa572154d     1
# 9c57789a6a587f4efcfb01e36c106014     1
# 9e4c21635f640562de1a6976374fba03     1
# 06c0ea6ee892364d1608ee47aa9f56a0     1
# 84732c5050c01db9b23e19ba39899398     1
# Name: count, Length: 96096, dtype: int64

# %%
# Understand the location information
customers["customer_state"].value_counts()
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
order_items.columns # order table
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# Check the data type of each column
order_items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
# Check how many missing values are in each column
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# See how many items some orders contain
order_items["order_id"].value_counts().head(10)
# Out:
# order_id
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
# 9bdc4d4c71aa1de4606060929dee888c    14
# 73c8ab38f07dc94389065f7eba4f297a    14
# 37ee401157a3a0b28c9c6d0ed8c3b24b    13
# 2c2a19b5703863c908512d135aa6accc    12
# c05d6a79e55da72ca780ce90364abed9    12
# Name: count, dtype: int64

# %%
# Check whether order_item_id repeats in the entire dataset
order_items["order_item_id"].duplicated().sum()
# Out:
# 112629

# %%
# Check whether the combination of order_id and order_item_id is duplicated
order_items.duplicated(
    subset=["order_id", "order_item_id"]
).sum()
# Out:
# 0

# %% [markdown]
# 0 means there are no duplicate combinations of order + item number.

# %%
# Products table
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Check data types
products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
# Check missing values
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# Check duplicate product IDs
products["product_id"].duplicated().sum()
# Out:
# 0

# %%
# Products with missing category
products[products["product_category_name"].isnull()].head()
# Out:
#                            product_id product_category_name  \
# 105  a41e356c76fab66334f36de622ecbd3a                   NaN
# 128  d8dee61c2034d6d075997acef1870e9b                   NaN
# 145  56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154  46b48281eb6d663ced748f324108c733                   NaN
# 197  5fb61f482620cb672f5e586bb132eae9                   NaN
#
#      product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                  NaN                         NaN                 NaN
# 128                  NaN                         NaN                 NaN
# 145                  NaN                         NaN                 NaN
# 154                  NaN                         NaN                 NaN
# 197                  NaN                         NaN                 NaN
#
#      product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 105             650.0               17.0               14.0              12.0
# ...

# %%
# Missing values among products with missing category
products[products["product_category_name"].isnull()].isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                1
# product_length_cm               1
# product_height_cm               1
# product_width_cm                1
# dtype: int64

# %%
# Products with missing weight
products[products["product_weight_g"].isnull()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
# Finding products with missing category
missing_category_products = products[
    products["product_category_name"].isnull()
]

# %%
# Check how many missing-category products were sold
missing_category_products["product_id"].isin(order_items["product_id"]).sum()
# Out:
# 610

# %%
# Check how many missing-category products were sold
missing_category_products["product_id"].isin(
    order_items["product_id"]
).sum()
# Out:
# 610

# %%
# Count order-item records linked to products with missing categories
order_items["product_id"].isin(
    missing_category_products["product_id"]
).sum()
# Out:
# 1603

# %%
# Calculate the percentage of order items affected
affected_items = order_items["product_id"].isin(
    missing_category_products["product_id"]
).sum()

total_items = len(order_items)

affected_percentage = affected_items / total_items * 100

print(f"Affected order items: {affected_items:,}")
print(f"Total order items: {total_items:,}")
print(f"Affected percentage: {affected_percentage:.2f}%")
# Out:
# Affected order items: 1,603
# Total order items: 112,650
# Affected percentage: 1.42%

# %% [markdown]
# 1.42% of all order-item records are linked to products with missing category information.

# %%
# Find products with missing weight
missing_weight_products = products[
    products["product_weight_g"].isnull()
]

# Check whether these products were sold
missing_weight_products["product_id"].isin(
    order_items["product_id"]
).sum()
# Out:
# 2

# %%
# Count order-item records linked to products with missing physical information
affected_physical_items = order_items["product_id"].isin(
    missing_weight_products["product_id"]
).sum()

print(f"Affected order items: {affected_physical_items:,}")
# Out:
# Affected order items: 18

# %%
# Check whether every sold product exists in the Products table
order_items["product_id"].isin(
    products["product_id"]
).sum()
# Out:
# 112650

# %%
# Total number of order-item records
len(order_items)
# Out:
# 112650

# %%
# Payment Table
# Payments table
payments.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
# Payments table
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# Check data types
payments.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
# Check missing values
payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# See orders with multiple payment records
payments["order_id"].value_counts().head(10)
# Out:
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352    29
# ccf804e764ed5650cd8759557269dc13    26
# 285c2e15bebd4ac83635ccc563dc71f4    22
# 895ab968e7bb0d5659d16cd74cd1650c    21
# fedcd9f7ccdc8cba3a18defedd1a5547    19
# ee9ca989fc93ba09a6eddc250ce01742    19
# 4bfcba9e084f46c8e3cb49b0fa6e6159    15
# 21577126c19bf11a0b91592e5844ba78    15
# 3c58bffb70dcf45f12bdf66a3c215905    14
# 4689b1816de42507a7d63a4617383c59    14
# Name: count, dtype: int64

# %%
# Check for duplicate payment records
payments.duplicated(
    subset=["order_id", "payment_sequential"]
).sum()
# Out:
# 0

# %%
# See the different payment methods
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
# Inspect the undefined payment records
payments[payments["payment_type"] == "not_defined"]
# Out:
#                                order_id  payment_sequential payment_type  \
# 51280  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value
# 51280                     1            0.0
# 57411                     1            0.0
# 94427                     1            0.0

# %%
# Count payment records by number of installments
payments["payment_installments"].value_counts().sort_index()
# Out:
# payment_installments
# 0         2
# 1     52546
# 2     12413
# 3     10461
# 4      7098
# 5      5239
# 6      3920
# 7      1626
# 8      4268
# 9       644
# 10     5328
# 11       23
# 12      133
# 13       16
# 14       15
# 15       74
# 16        5
# 17        8
# 18       27
# 20       17
# 21        3
# 22        1
# 23        1
# 24       18
# Name: count, dtype: int64

# %%
# Inspect payments with zero installments
payments[payments["payment_installments"]==0]
# Out:
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 79014  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69
# 79014                     0         129.94

# %%
# Summary of payment values
payments["payment_value"].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
# Reviews table
reviews.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
reviews.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews["review_id"].duplicated().sum()
# Out:
# 814

# %%
# Check review score distribution
reviews["review_score"].value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
# Find duplicated review IDs
duplicated_reviews = reviews[
    reviews["review_id"].duplicated(keep=False)
]

duplicated_reviews.head(20)
# Out:
#                              review_id                          order_id  \
# 200   28642ce6250b94cc72bc85960aec6c62  e239d280236cdd3c40cb2c033f681d1c
# 344   a0a641414ff718ca079b3967ef5c2495  169d7e0fd71d624d306f132acd791cbe
# 346   f4d74b17cd63ee35efa82cd2567de911  f269e83a82f64baa3de97c2ebf3358f6
# 360   ecbaf1fce7d2c09bfab46f89065afeaf  2451b9756f310d4cff5c7987b393870d
# 393   6b1de94de0f4bd84dfc4136818242faa  92acf87839903a94aeca0e5040d99acb
# 433   957011305e7a4b6c8a266eeeb8e0316d  54b4da510fed5dc3cf3e7a8e50a5f224
# 508   b34f4a786bf00b7c8486141ba482783b  b2501eb5c292d415f52576b3d4b5de74
# 661   d433c252647c51309432ca0b763f969b  448795135b904d057254f5fd0d5a6a4c
# 723   5f35bbde2b32b8617aab15b7a9a0ae24  ba568688e2f462d7c44a3fdc62e6456f
# 764   c5976a5a98e854fb23d7e03c6754ae60  2002ea16e75277eaa0b5d78632048540
# 778   62c7722239b976d943ec0d430cfe890e  1d297b4800ed1a3c5b0944d84c01ee99
# 795   ca8e5e40f55fbffaa631de686b627dde  bce7047b261dd5116e87384f4fe9afc1
# ...

# %%
# Check how many reviews each order has
reviews["order_id"].value_counts().head(10)
# Out:
# order_id
# c88b1d1b157a9999ce368f218a407141    3
# 8e17072ec97ce29f0e1f111e598b0c85    3
# df56136b8031ecd28e200bb18e6ddb2e    3
# 03c939fd7fd3b38f8485a0f95798f1f6    3
# 5cb890a68b91b6158d69257e4e2bc359    2
# 2143393cca994a4b8235bc1d67ded772    2
# 25320e12b3d6e8f54f17389037588bba    2
# 0176a6846bcb3b0d3aa3116a9a768597    2
# d9e44c3fd2ce16086619f299e92e12d8    2
# 21cb4961399b846b168d0358100f473b    2
# Name: count, dtype: int64

# %%
# Check how many different orders use each duplicate review ID
duplicate_reviews.groupby("review_id")["order_id"].nunique().value_counts()
# Out:
# order_id
# 2    764
# 3     25
# Name: count, dtype: int64

# %%
# Check for completely duplicate review records
reviews.duplicated().sum()
# Out:
# 0

# %%
# Calculate percentage of each review score
reviews["review_score"].value_counts(normalize=True).sort_index() * 100
# Out:
# review_score
# 1    11.513344
# 2     3.175643
# 3     8.242965
# 4    19.291704
# 5    57.776344
# Name: proportion, dtype: float64

# %%
# Check how many reviews have a comment message
reviews["review_comment_message"].notnull().sum()
# Out:
# 40977

# %%
# Check how many reviews have no comment message
reviews["review_comment_message"].isnull().sum()
# Out:
# 58247

# %%
# Check how many reviews have a title
reviews["review_comment_title"].notnull().sum()
# Out:
# 11568

# %%
# Check the review creation date range
reviews["review_creation_date"].min(), reviews["review_creation_date"].max()
# Out:
# ('2016-10-02 00:00:00', '2018-08-31 00:00:00')

# %%
# Check the review answer date range
reviews["review_answer_timestamp"].min(), reviews["review_answer_timestamp"].max()
# Out:
# ('2016-10-07 18:32:28', '2018-10-29 12:27:35')

# %%
# Check the minimum and maximum review score
reviews["review_score"].min(), reviews["review_score"].max()
# Out:
# (1, 5)

# %%
# Check whether any invalid review scores exist
reviews[~reviews["review_score"].isin([1, 2, 3, 4, 5])].shape[0]
# Out:
# 0

# %%
# Sellers table
sellers.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
# Check for duplicate seller IDs
sellers["seller_id"].duplicated().sum()
# Out:
# 0

# %%
# Understand seller distribution by state
sellers["seller_state"].value_counts()
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# RN       5
# MS       5
# MT       4
# RO       2
# SE       2
# PI       1
# AC       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64

# %%
# Understand seller distribution by city
sellers["seller_city"].value_counts().head(15)
# Out:
# seller_city
# sao paulo                694
# curitiba                 127
# rio de janeiro            96
# belo horizonte            68
# ribeirao preto            52
# guarulhos                 50
# ibitinga                  49
# santo andre               45
# campinas                  41
# maringa                   40
# sao jose do rio preto     33
# sao bernardo do campo     32
# sorocaba                  32
# osasco                    32
# porto alegre              28
# Name: count, dtype: int64

# %%
# Check for completely duplicated seller records
sellers.duplicated().sum()
# Out:
# 0

# %%
# Check how many sellers have sold at least one item
sellers["seller_id"].isin(order_items["seller_id"]).sum()
# Out:
# 3095

# %%
# Check whether every order-item seller exists in the sellers table
order_items["seller_id"].isin(sellers["seller_id"]).sum()
# Out:
# 112650

# %%
# Total order-item records
len(order_items)
# Out:
# 112650

# %%
# Category Translation table
category_translation.columns
# Out:
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
category_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Check data types
category_translation.dtypes
# Out:
# product_category_name            object
# product_category_name_english    object
# dtype: object

# %%
# Check missing values
category_translation.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
# Check duplicate Portuguese category names
category_translation["product_category_name"].duplicated().sum()
# Out:
# 0

# %%
# Check duplicate English category names
category_translation["product_category_name_english"].duplicated().sum()
# Out:
# 0

# %%
# Get unique product categories
product_categories = products["product_category_name"].dropna().unique()

# Check how many have a translation
sum(
    category in category_translation["product_category_name"].values
    for category in product_categories
)
# Out:
# 71

# %% [markdown]
# Verify the key relationships

# %%
# Check whether every order belongs to a known customer
orders["customer_id"].isin(customers["customer_id"]).sum()
# Out:
# 99441

# %%
# Total number of orders
len(orders)
# Out:
# 99441

# %%
# Check how many customers have at least one order
customers["customer_id"].isin(orders["customer_id"]).sum()
# Out:
# 99441

# %%
# Total customers
len(customers)
# Out:
# 99441

# %%
# Check how many orders have at least one order item
orders["order_id"].isin(order_items["order_id"]).sum()
# Out:
# 98666

# %%
# Total number of orders
len(orders)
# Out:
# 99441

# %% [markdown]
# Orders with at least one item     98,666
#
# Total orders                      99,441
#
# Orders without an item               775
#
# So 775 orders do not have any record in order_items.

# %%
# Find orders that have no order-item records
orders_without_items = orders[
    ~orders["order_id"].isin(order_items["order_id"])
]

# Check their order statuses
orders_without_items["order_status"].value_counts()
# Out:
# order_status
# unavailable    603
# canceled       164
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
# Check whether every order item belongs to a known order
order_items["order_id"].isin(orders["order_id"]).sum()
# Out:
# 112650

# %%
# Total order-item records
len(order_items)
# Out:
# 112650

# %%
# Check whether every order item belongs to a known product
order_items["product_id"].isin(products["product_id"]).sum()

# Total order-item records
len(order_items)
# Out:
# 112650

# %%
# Check how many products have been sold at least once
products["product_id"].isin(order_items["product_id"]).sum()

# Total number of products
len(products)
# Out:
# 32951

# %%
order_items["seller_id"].isin(sellers["seller_id"]).sum()
# Out:
# 112650

# %%
# Check whether every order item belongs to a known product
order_items["product_id"].isin(products["product_id"]).sum()

# Total order-item records
len(order_items)
# Out:
# 112650

# %%
# Check how many products have been sold at least once
products["product_id"].isin(order_items["product_id"]).sum()

# Total number of products
len(products)
# Out:
# 32951

# %%
# Find products that have no corresponding order-item record
unsold_products = products[
    ~products["product_id"].isin(order_items["product_id"])
]

# Number of unsold products
len(unsold_products)
# Out:
# 0

# %%
# Check the categories of products that were never sold
unsold_products["product_category_name"].value_counts().head(15)
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Check whether every payment record belongs to a known order
payments["order_id"].isin(orders["order_id"]).sum()

# Total payment records
len(payments)
# Out:
# 103886

# %%
# Check how many orders have at least one payment record
orders["order_id"].isin(payments["order_id"]).sum()

# Total number of orders
len(orders)
# Out:
# 99441

# %%
# Convert order date columns to datetime
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_columns:
    orders[col] = pd.to_datetime(orders[col])

orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
# Order items
# Convert shipping date to datetime
order_items["shipping_limit_date"] = pd.to_datetime(
    order_items["shipping_limit_date"]
)

# %%
# Reviews
# Convert review dates to datetime
reviews["review_creation_date"] = pd.to_datetime(
    reviews["review_creation_date"]
)

reviews["review_answer_timestamp"] = pd.to_datetime(
    reviews["review_answer_timestamp"]
)

# %%
import sqlite3

# Create SQLite database
conn = sqlite3.connect(
    r"C:\Users\91776\Downloads\Olist-Ecommerce-Business-Analysis\olist.db"
)

# %%
customers.to_sql("customers", conn, if_exists="replace", index=False)
geolocation.to_sql("geolocation", conn, if_exists="replace", index=False)
orders.to_sql("orders", conn, if_exists="replace", index=False)
order_items.to_sql("order_items", conn, if_exists="replace", index=False)
payments.to_sql("payments", conn, if_exists="replace", index=False)
reviews.to_sql("reviews", conn, if_exists="replace", index=False)
products.to_sql("products", conn, if_exists="replace", index=False)
sellers.to_sql("sellers", conn, if_exists="replace", index=False)
category_translation.to_sql(
    "category_translation",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 71
